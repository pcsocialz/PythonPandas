# %%
# Following Topics are covered in this note

# Creating DataFrame
# Rows and Column operation
# Indexing

# %%
import pandas as pd

# %%
#Creating a dictionary object
weatherData={
    'Date':['1/1/2019','1/2/2019','1/3/2019','1/4/2019'],
    'Temperature':['36','37','38','39'],
    'Windspeed':['1','3','7','9'],
    'Event':['Rain','Sunny','Cloudy','Snow']
}

# %%
# Use below command to transform into Dataframe 
df1=pd.DataFrame(weatherData)
df1
# Out:
#        Date Temperature Windspeed   Event
# 0  1/1/2019          36         1    Rain
# 1  1/2/2019          37         3   Sunny
# 2  1/3/2019          38         7  Cloudy
# 3  1/4/2019          39         9    Snow

# %%
# Reading csv using read csv command directly
df2=pd.read_csv("district wise rainfall normal.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f2b005023214> in <module>()
#       1 # Reading csv using read csv command directly
# ----> 2 df2=pd.read_csv("district wise rainfall normal.csv")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'district wise rainfall normal.csv' does not exist

# %%
# To get the dimensions(No of Rows & No of Columns) of DataFrame use following command, Output is a tuple
df2.shape

# %%
# If we wish to store rows and columns do following way.
rows,columns=df2.shape

# %%
rows

# %%
columns

# %%
# If we want to print only initial few rows in data frame use following command
df2.head()

# %%
# If we want to print only last few rows in data frame use following command
df2.tail()

# %%
# If we want to print certain no.of initial rows or last rows use following command

df2.head(10)
df2.tail(10)

# %%
# Let's say if want to print only from row 2 to 10 use below command (It includes row 2 but not row 10)
df2[2:10]

# %%
#If want to print everything follow as below
df2[:] 
#(or) 
df2

# %%
# If we wish to print column names use below command
df2.columns

# %%
# If we want to print the content of the particular column use following command
df2.DISTRICT 
#(Or)
df2['DISTRICT']

# %%
type(df2['DISTRICT']) # Columns are in Dataframes are type Pandas Series

# %%
# If we want to restrict certain columns or to get only certain columns use below command
df2[['DISTRICT','OCT']]

# %%
#If we want to find the maximum & Minimum values in any column data use following command
df2['OCT'].max()
df2['OCT'].min()

# %%
#If we want get statistical Data use following command
df2.describe()

# %%
# If we want get data in dataframe using condition (This is similar to SQL Query)
df2[df2.OCT>=100]

# %%
# If we want to get the max value in OCT using condition as follows
df2[df2.OCT==df2.OCT.max()]
#(OR)
df2[df2.OCT==df2['OCT'].max()] # This we'll prefer incase if columns are having any spaces

# %%
#If we want to know the state where weather where max rainfall in Oct month
df2[['STATE_UT_NAME','DISTRICT']][df2.OCT==df2['OCT'].max()]

# %%
df2.reset_index(inplace=True)

# %%
#If we want to know index of DataFrame
df2.index

# %%
#If we want to set any particular column as index do as below
df2.set_index('DISTRICT')
# Out:
#                               STATE_UT_NAME    JAN    FEB    MAR    APR  \
# DISTRICT
# NICOBAR         ANDAMAN And NICOBAR ISLANDS  107.3   57.9   65.2  117.0
# SOUTH ANDAMAN   ANDAMAN And NICOBAR ISLANDS   43.7   26.0   18.6   90.5
# N & M ANDAMAN   ANDAMAN And NICOBAR ISLANDS   32.7   15.9    8.6   53.4
# LOHIT                     ARUNACHAL PRADESH   42.2   80.8  176.4  358.5
# EAST SIANG                ARUNACHAL PRADESH   33.3   79.5  105.9  216.5
# SUBANSIRI F.D             ARUNACHAL PRADESH   28.0   48.3   85.3  101.5
# TIRAP                     ARUNACHAL PRADESH   42.2   72.7  141.0  316.9
# ANJAW (LOHIT)             ARUNACHAL PRADESH   42.2   80.8  176.4  358.5
# LOWER DIBANG              ARUNACHAL PRADESH   83.7  153.9  303.5  383.6
# CHANGLANG                 ARUNACHAL PRADESH   70.3  170.9  367.9  554.4
# PAPUM PARE                ARUNACHAL PRADESH   33.5   67.8  106.1  226.9
# LOW SUBANSIRI             ARUNACHAL PRADESH   97.5  109.3   92.4  204.3
# UPPER SIANG               ARUNACHAL PRADESH   74.3  176.7  362.6  397.5
# WEST SIANG                ARUNACHAL PRADESH   26.0   66.7   76.8  229.2
# DIBANG VALLEY             ARUNACHAL PRADESH   83.7  153.9  303.5  383.6
# WEST KAMENG               ARUNACHAL PRADESH   35.2   43.5   58.9  134.3
# EAST KAMENG               ARUNACHAL PRADESH   49.0   74.4   96.5  156.9
# TAWANG(W KAME             ARUNACHAL PRADESH   35.2   43.5   58.9  134.3
# KURUNG KUMEY              ARUNACHAL PRADESH   82.7   70.0  128.2  245.7
# CACHAR                                ASSAM   13.3   50.2  168.3  262.5
# DARRANG                               ASSAM   13.1   21.4   53.5  168.8
# GOALPARA                              ASSAM   12.7   20.4   51.1  196.6
# KAMRUP                                ASSAM   12.0   20.8   58.6  151.7
# LAKHIMPUR                             ASSAM   27.7   48.6   76.7  165.5
# NORTH CACHAR                          ASSAM   16.7   47.5  158.9  207.9
# NAGAON                                ASSAM   12.0   22.5   48.1  128.9
# SIVASAGAR                             ASSAM   20.1   33.2   78.3  126.5
# BARPETA                               ASSAM   10.3   26.9   54.0  175.7
# DHUBRI                                ASSAM   10.3   11.7   46.6  147.5
# DIBRUGARH                             ASSAM   30.6   53.1  119.8  229.9
# ...                                     ...    ...    ...    ...    ...
# BELLARY                           KARNATAKA    1.4    1.4    2.9   26.2
# CHIKMAGALUR                       KARNATAKA    1.6    2.0   12.0   60.2
# CHITRADURGA                       KARNATAKA    1.4    1.2    4.4   25.8
# KODAGU                            KARNATAKA    3.5    4.2   18.5   89.8
# HASSAN                            KARNATAKA    1.3    2.5   10.7   55.1
# KOLAR                             KARNATAKA    2.7    4.5   10.4   27.8
# MANDYA                            KARNATAKA    1.9    3.6    7.6   45.3
# MYSORE                            KARNATAKA    2.5    3.5   11.4   58.7
# SHIMOGA                           KARNATAKA    0.5    0.4    6.3   38.0
# TUMKUR                            KARNATAKA    2.4    3.0    7.1   34.0
# BANGALORE URB                     KARNATAKA    2.3    6.7    8.2   39.2
# CHAMARAJANAGA                     KARNATAKA    3.4    6.0   13.2   69.2
# DAVANGERE                         KARNATAKA    1.1    0.8    4.2   35.0
# RAMNAGAR(BNGR)                    KARNATAKA    1.5    4.7   10.2   47.9
# CHICKBALLAPUR                     KARNATAKA    2.1    4.6    8.2   27.2
# ALAPPUZHA                            KERALA   17.5   27.9   45.1  134.0
# CANNUR                               KERALA    2.5    2.0    7.6   57.9
# ERNAKULAM                            KERALA   13.2   18.8   31.2  112.0
# KOTTAYAM                             KERALA   13.0   24.9   42.3  136.1
# KOZHIKODE                            KERALA    2.3    3.9   15.1   80.9
# MALAPPURAM                           KERALA    1.7    3.9   12.7   86.8
# PALAKKAD                             KERALA    2.9    6.5   22.5   98.7
# KOLLAM                               KERALA   17.5   33.7   62.6  158.5
# UPPER SIANG     4402.1    251.0   1168.8   2558.8    423.5
# WEST SIANG      2440.7     92.7    545.5   1612.5    190.0
# DIBANG VALLEY   2553.3    237.6    955.1   1073.4    287.2
# WEST KAMENG     3399.4     78.7    534.3   2485.2    301.2
# EAST KAMENG     2030.9    123.4    461.4   1246.3    199.8
# TAWANG(W KAME   3399.4     78.7    534.3   2485.2    301.2
# KURUNG KUMEY    2221.5    152.7    645.3   1256.5    167.0
# CACHAR          2999.2     63.5    817.2   1889.9    228.6
# DARRANG         1957.8     34.5    542.3   1259.1    121.9
# GOALPARA        2575.3     33.1    647.5   1710.1    184.6
# KAMRUP          1813.4     32.8    503.7   1147.7    129.2
# LAKHIMPUR       2859.3     76.3    574.1   2025.2    183.7
# NORTH CACHAR    1977.5     64.2    674.8    988.8    249.7
# NAGAON          1660.1     34.5    348.3   1124.9    152.4
# SIVASAGAR       1811.6     53.3    461.9   1169.5    126.9
# BARPETA         3274.6     37.2    621.2   2441.0    175.2
# DHUBRI          2702.6     22.0    585.7   1916.5    178.4
# DIBRUGARH       2556.6     83.7    642.1   1651.4    179.4
# ...                ...      ...      ...      ...      ...
# BELLARY          622.8      2.8     87.0    376.0    157.0
# CHIKMAGALUR     2077.5      3.6    178.1   1657.3    238.5
# CHITRADURGA      527.7      2.6     95.1    271.0    159.0
# KODAGU          2741.4      7.7    261.0   2181.9    290.8
# HASSAN           967.1      3.8    168.0    574.3    221.0
# KOLAR            731.1      7.2    112.6    382.7    228.6
# MANDYA           662.7      5.5    158.0    285.1    214.1
# MYSORE           758.6      6.0    194.7    343.6    214.3
# SHIMOGA         1827.9      0.9    122.6   1514.0    190.4
# TUMKUR           698.5      5.4    128.2    359.2    205.7
# BANGALORE URB    870.0      9.0    153.7    475.7    231.6
# CHAMARAJANAGA    788.4      9.4    213.6    320.6    244.8
# DAVANGERE        676.7      1.9    113.2    384.9    176.7
# RAMNAGAR(BNGR)   883.7      6.2    180.4    454.0    243.1
# CHICKBALLAPUR    748.5      6.7    104.8    411.8    225.2
# ALAPPUZHA       2841.2     45.4    477.8   1745.9    572.1
# CANNUR          3319.1      4.5    300.5   2669.0    345.1
# ERNAKULAM       3029.9     32.0    443.6   2065.0    489.3
# KOTTAYAM        2930.5     37.9    460.2   1897.3    535.1
# KOZHIKODE       3384.1      6.2    352.6   2603.1    422.2
# MALAPPURAM      2835.1      5.6    320.8   2060.4    448.3
# PALAKKAD        2290.0      9.4    279.9   1572.7    428.0
# KOLLAM          2491.7     51.2    469.6   1332.3    638.6
# THRISSUR        3063.1     10.9    385.3   2197.5    469.4
# THIRUVANANTHA   1803.2     40.4    368.8    871.3    522.7
# IDUKKI          3302.5     35.5    426.6   2276.2    564.2
# KASARGOD        3621.6      3.3    272.9   3007.5    337.9
# PATHANAMTHITTA  2958.4     65.0    553.5   1715.7    624.2
# WAYANAD         3253.1     13.1    275.4   2632.1    332.5
# LAKSHADWEEP     1600.0     35.5    232.4    998.5    333.6
#
# [641 rows x 18 columns]

# %%
df2.loc['KOZHIKODE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [KOZHIKODE] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-7209b8d3b445> in <module>()
# ----> 1 df2.loc['KOZHIKODE']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [KOZHIKODE] is not in the [index]'
